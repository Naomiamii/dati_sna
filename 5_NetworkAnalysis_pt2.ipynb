# %% [markdown]
# <a href="https://colab.research.google.com/github/Naomiamii/dati_sna/blob/main/5_NetworkAnalysis_pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns
import json

# %%
from cdlib import algorithms
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'wurlitzer', 'leidenalg', 'karateclub', 'graph_tool', 'infomap'}
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'ASLPAw', 'karateclub'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'leidenalg', 'wurlitzer', 'infomap'}

# %%
path_subgraph = "../DataSet FFF/Graph_data/"

# %%
def plot_centralities(first, name_f, second, name_s, third, name_t, n):

    lista = [(k, v) for k, v in first.items()]
    lista.sort(key=lambda x: x[1], reverse = True)
    tops = lista[:n]
    first_ = []
    second_ = []
    third_ = []
    for i in tops:
        first_.append(first[i[0]])
        second_.append(second[i[0]])
        third_.append(third[i[0]])
        
    tops = [i for i,j in tops]
    tops = tops[::-1]
    first_ = first_[::-1]
    second_ = second_[::-1]
    third_ = third_[::-1]
    
    fig = plt.figure(figsize = (25,8), dpi = 300)

    fontsize = 17
    plt.rcParams.update({'font.size': fontsize})
    ax = fig.add_subplot(151)
    plt.barh(tops,first_, color = "#31A894")
    plt.grid(axis = 'both', alpha = .3)
    plt.xlabel(name_f)

    ax2 = fig.add_subplot(152)
    plt.barh(tops,second_, color = "#315FA8")
    plt.grid(axis = 'both', alpha = .3)
    plt.setp(ax2.get_yticklabels(), visible = False)
    plt.xlabel(name_s)

    ax3 = fig.add_subplot(153)
    plt.barh(tops,third_, color = "#5D2FA5")
    plt.grid(axis = 'both', alpha = .3)
    plt.setp(ax3.get_yticklabels(), visible = False)
    plt.xlabel(name_t)
    plt.show()

# %%
path_graph = "/content/"

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
ba_G = nx.read_graphml(path_graph+"BA_Network.graphml")
er_G = nx.read_graphml(path_graph+"ER_Network.graphml")
ws_G = nx.read_graphml(path_graph+"WS_Network.graphml")
cm_G = nx.read_graphml(path_graph+"CM_Network.graphml")

# %%
models = {
    "Real Network": G,
    "Barabasi Albert": ba_G,
    "Erdos Renyi": er_G,
    "Watts Strogatz": ws_G,
    "Configuration Model": cm_G
}

# %% [markdown]
# # 1 - Degree Centrality

# %%
degree_centrality = nx.degree_centrality(G)

# %%
new_centrality_nodes = [k for k, v in sorted(degree_centrality.items(), key=lambda item: item[1], reverse = True)]
new_df = pd.DataFrame({"Id": new_centrality_nodes})
new_df.to_csv("/content/centrality_degree_nodes.csv", index=False)

# %% [markdown]
# # 2 - Connectivity Based Centrality

# %%
eigenvector_centrality = nx.eigenvector_centrality(G, weight='Count',  max_iter=1000)

# %% [markdown]
# # 3 - PageRank centrality

# %%
pagerank_centrality = nx.pagerank(G, weight='Count', max_iter=1000)

# %%
nx.pagerank??

# %% [markdown]
# # 4 - Geometric Centrality

# %%
closeness_centrality = nx.closeness_centrality(G)

# %%
harmonic_centrality = nx.harmonic_centrality(G)

# %%
betweenness_centrality = nx.betweenness_centrality(G, weight='Count')

# %% [markdown]
# Plot

# %%
plot_centralities(degree_centrality, "Degree", eigenvector_centrality, "Eigenvector", pagerank_centrality, "PageRank", 15)

# %%
plot_centralities(closeness_centrality, "Closeness", betweenness_centrality, "Betweeneess", harmonic_centrality, "Harmonic", 15)

# %%
lista = [(k, v) for k, v in degree_centrality.items()]
lista.sort(key=lambda x: x[1], reverse = True)
tops = lista[:20]
tops = [i for i,j in tops]
H = G.subgraph(tops)
nx.write_gexf(H, "/content/centrality_subgraph.gexf")

# %% [markdown]
# # Storing central nodes

# %%
betweenness_centrality
# Out:
# {'fossilfuels': 0.0005319918039579404,
#  'wind': 0.0004970327415823355,
#  'solar': 0.0003218921833596707,
#  'green': 0.000246917562204923,
#  'hydrogen': 4.874855393233214e-05,
#  'energy': 0.0005918873446869339,
#  'climateaction': 0.02168911829982135,
#  'renewableenergy': 0.00023495587809175956,
#  'carbon': 0.00011483296422085737,
#  'demvoice1': 9.610357433143683e-05,
#  'sdgs': 0.0012152812337959528,
#  'climatecrisis': 0.01355344907936887,
#  'fridaysforfuture': 0.6816863280124034,
#  'peoplenotprofit': 0.0017954452716789399,
#  'climatestrike': 0.04391790154951685,
#  'climate': 0.00378432360189186,
#  'actnow': 0.004593092762825182,
#  'climateemergency': 0.012432012459202045,
#  'climateactionnow': 0.0062485221536739965,
#  'uprootthesystem': 0.0028426267242681385,
#  'earth': 0.00046961945099204867,
#  'climatejustice': 0.005924333358321453,
#  'planet': 0.0005467589932784032,
#  'stopeacop': 0.00031853828222324276,
#  'climatestrikeonline': 0.0063975815881270525,
#  'schoolstrike4climate': 0.005963857177678588,
#  'savesoil': 0.00014280477718445162,
#  'climatechange': 0.01524554733273423,
#  'facetheclimateemergency': 0.0037264621996501114,
#  'standwithukraine️': 6.302886811758333e-05,
#  'conservation': 0.00026547252609858185,
#  'energytransition': 8.995175613969791e-05,
#  'future': 0.0005414869321281319,
#  'sustainability': 0.0008109777109119618,
#  'renewables': 0.0005209458004760337,
#  'gas': 0.0006248380033320423,
#  'digitalstrike': 0.0025348310422742236,
#  'boomersforclimatejustice': 0.0001859198986271941,
#  'systemchange': 0.0009219672793193178,
#  'twiff': 0.00014187625638008316,
#  'solarenergy': 5.503727885052263e-05,
#  'gretathunberg': 0.013649651526025167,
#  'environment': 0.0011212478660599333,
#  'cleanenergy': 0.00012747962103485975,
#  'pollution': 0.00020800611345498575,
#  'stopcambo': 2.5357966426396752e-05,
#  'india': 0.0010037070736767836,
#  'fridaymotivation': 0.004752052647350135,
#  'australia': 0.0004665955416229058,
#  'justtransition': 0.00033866660357014113,
#  'stockholm50': 8.46937791767258e-05,
#  'ilmastolakko': 4.351349368148669e-05,
#  'oil': 6.543158124876797e-05,
#  'eusolidaritycorps': 2.207074402677754e-05,
#  'environmentaljustice': 0.0001774310910270385,
#  'markcarney': 2.0933476791290278e-05,
#  'sweden': 9.692137148490401e-05,
#  'ecocide': 0.00027096309043511587,
#  'fossil': 0.00016748353960700237,
#  'carbondioxide': 3.2853465787450768e-06,
#  'earthday2022': 4.271546106537671e-05,
#  'earthday': 0.0008927372854161904,
#  'nomoreemptypromises': 0.0025705184430440033,
#  'greenenergy': 9.006829440478697e-05,
#  'greennewdeal': 0.0012525129822215158,
#  'earthkeepersunite': 3.173369294565812e-05,
#  'cop26': 0.003242195442718593,
#  'greenwashing': 0.00019402332912201497,
#  'oilprices': 4.344803425711691e-05,
#  'covid19': 0.0024132847924200405,
#  'putinswar': 3.162475817197314e-06,
#  'bigoil': 4.2162029334817745e-06,
#  'oligarchs': 0.0002354910100891092,
#  'peace4climate': 2.579974471129687e-06,
#  'coal': 0.00018696429704540866,
#  'wws': 1.7752066411651073e-06,
#  'cop26glasgow': 0.00028753856349785113,
#  'policymakers': 2.988781418447625e-05,
#  'wtpearth': 3.343171953960931e-05,
#  'methane': 0.00023994412997060325,
#  'kohleausstieg': 0.002030127283534091,
#  'sustainablesolutions': 3.217391749187227e-05,
#  'nytonpakko': 0.00018155286509065327,
#  'fairshare': 4.929111485883123e-06,
#  'animalagriculture': 0.0,
#  'nitrousoxide': 0.00014222358230322097,
#  'justtransitionmossmorran': 3.1486415313073465e-06,
#  'planetb': 5.545390754405615e-05,
#  'factoryfarming': 6.776000132026355e-06,
#  'climagechange': 1.0134453201258288e-05,
#  'irtiturpeesta': 3.8089118110694715e-08,
#  'zerowaste': 0.00013192838420094307,
#  'vote': 1.921276449275242e-05,
#  'supplychains': 4.771244379399989e-05,
#  'eni': 1.3830932804890679e-05,
#  '27novembre': 2.859824097274429e-05,
#  'win': 0.00011684320147061898,
#  'washingtondc': 3.146956615102945e-08,
#  'frontline': 0.00016407165535472574,
#  'fridayforfuture': 0.05442216072282206,
#  'oceans': 0.00013749879094932825,
#  'water': 0.0002768153260935627,
#  'cleatech': 8.97886620929465e-05,
#  'innovation': 0.00029916405991786156,
#  'africa': 4.730099740247682e-05,
#  'sustainable': 0.00013905405869063235,
#  'co2': 0.0035025962166720477,
#  'tech': 0.0002192592671786205,
#  'extinctionrebellion': 0.007094939020265746,
#  'energiewende': 0.005887419278702835,
#  'uk': 0.0003923329824138017,
#  'science': 0.0008388407235626109,
#  'economy': 1.6155542213320125e-05,
#  'jobs': 4.889424565303582e-05,
#  'europe': 0.00011308765669551091,
#  'ghg': 9.816013756732404e-05,
#  'actonclimate': 0.0015406020056667254,
#  'fridayvibes': 0.0017624782591902637,
#  'storage': 5.1347241475744844e-05,
#  'engineering': 2.9702645743472194e-05,
#  'ev': 9.62894593634279e-05,
#  'eu': 0.0005495777536131291,
#  'russian': 7.39278098335771e-05,
#  'energyefficiency': 6.4540392373035405e-06,
#  'greendeal': 0.0003647253993359406,
#  'electric': 2.846533277929059e-05,
#  'sustainabilty': 1.0792500391299108e-05,
#  'endcoal': 0.0005677380116764309,
#  'electricity': 4.839946828709353e-05,
#  'goodmorningeveryone': 2.3025730701103357e-05,
#  'erneuerbare': 0.00021832546020155108,
#  'fridaythoughts': 0.0031626388014729277,
#  'cleantech': 4.082152983553429e-06,
#  'technology': 0.0001459206443811125,
#  'air': 8.364926070060075e-06,
#  'israel': 0.0005458027269708572,
#  'economic': 2.827566684744618e-05,
#  'china': 0.00044641524910578,
#  'klimaneutralität': 0.00023073952842337097,
#  'us': 7.472775191113846e-05,
#  'thoughts': 3.055042261296874e-05,
#  'atmosphere': 0.00011159064283783355,
#  'ng': 6.825511000933312e-05,
#  'rt': 0.0005544420094371122,
#  'power': 5.3337092109418286e-05,
#  'job': 0.00015400736457329693,
#  'renewbleenergy': 1.906186051745575e-06,
#  'beauty': 1.6031393723958512e-05,
#  'morning': 2.1939690286349642e-06,
#  'freshness': 5.737183469202425e-05,
#  'emotions': 5.737183469202425e-05,
#  'ideas': 5.737183469202425e-05,
#  'norway': 4.0245940665577826e-05,
#  'akkus': 2.3547730838358868e-07,
#  'disruption': 2.3547730838358868e-07,
#  'ee': 3.994672539082586e-06,
#  'eeg2021': 2.560475828456976e-05,
#  'pv': 0.0003380660776946303,
#  'klimaneutral2050': 1.8742346650481374e-06,
#  'city': 0.0008116558929036208,
#  'renewable': 1.3649095588262216e-05,
#  'islands': 7.444360032781718e-05,
#  'clmatecrisis': 6.0211774101805074e-05,
#  'mauritius': 0.00011163264553944258,
#  'geothermal': 3.2792677030542e-05,
#  'innovations': 7.139554543992015e-05,
#  'industry': 8.424308254497926e-05,
#  'investing': 4.3257251141313925e-05,
#  'canberra': 0.00012909463362235804,
#  'efficiency': 1.078108534045081e-05,
#  're100': 0.00012909463362235804,
#  'klimakrise': 0.019548675466743506,
#  'berlin': 0.004219486186359608,
#  'emissions': 8.178355719451362e-05,
#  'netzero': 7.38617637376908e-05,
#  'nuclear': 0.0005294108260571323,
#  'heatwave': 6.92843736564538e-05,
#  'fossilfuel': 0.00016443289041021502,
#  'japan': 0.00018731812207131978,
#  'solarpower': 1.7443120059174034e-05,
#  'transportation': 3.574730268403951e-05,
#  'klimastreik': 0.012901527211645761,
#  'deutschland': 0.001799703090681078,
#  'germany': 0.0002904873836707327,
#  'mobile': 6.689377047468291e-05,
#  'zero': 6.689377047468291e-05,
#  'kernenergie': 0.00010536521320451537,
#  'france': 0.0001380460575265275,
#  'polluting': 1.6557222667208515e-05,
#  'scottish': 8.64374352474602e-05,
#  'ecudaor': 3.734728484234974e-05,
#  'electrify': 1.1232251631779573e-05,
#  'atom': 4.4055350218481735e-05,
#  'cambioclimático': 0.000998125572687722,
#  'dontchooseextinction': 1.4749277228142095e-05,
#  'singapore': 5.33751889552491e-06,
#  'california': 3.566426375934581e-05,
#  'ice': 3.219170687520961e-05,
#  'sun': 5.3928180159705286e-05,
#  'decarbonization': 6.645966073122208e-05,
#  'trains': 6.645966073122208e-05,
#  'eeg': 5.832099282063452e-05,
#  'house': 4.550968406763217e-05,
#  'panelsnotpipelines': 0.0,
#  'klimapaket': 0.0029299824574204798,
#  'buildings': 7.574325921636988e-05,
#  'abfckpraemie': 0.00035036577152408463,
#  'home': 6.628183523619305e-05,
#  'schweiz': 7.129131934936244e-05,
#  'solarwirtschaft': 2.6251582644764945e-07,
#  'speicher': 2.6251582644764945e-07,
#  'es2050': 2.6251582644764945e-07,
#  '10vor10': 2.6251582644764945e-07,
#  'wärme': 2.6251582644764945e-07,
#  'waermeinitiative': 2.6251582644764945e-07,
#  'co2gesetz': 0.0004916644364248952,
#  'gretathurnberg': 0.0002508220843070569,
#  'az': 9.39616463994861e-05,
#  'microgrid': 7.57521214213269e-06,
#  'galapagos': 7.57521214213269e-06,
#  'energystorage': 7.57521214213269e-06,
#  'euw19': 7.57521214213269e-06,
#  'siemensinfluencer': 7.57521214213269e-06,
#  'srfclub': 0.0004732403356876453,
#  'ug4ph': 5.596664957852296e-05,
#  'solarpanel': 5.216497696084951e-05,
#  'globalwarming': 0.00030006814199858234,
#  'fridayfeeling': 0.003955339038055478,
#  'fridays4future': 0.001338358763779036,
#  'life': 0.00013663186902904725,
#  'nature': 0.0012138575069767525,
#  'vegan': 0.0008338868291758377,
#  'giornatamondialedellambiente': 7.57157097019059e-05,
#  'weekend': 0.0001509846974127884,
#  'consigli': 2.1098991245534365e-05,
#  'viaggio': 2.1098991245534365e-05,
#  'viaggiare': 7.57157097019059e-05,
#  'ambiente': 0.0006044405606478069,
#  'travel': 0.0003171974544116775,
#  'worldenvironmentday': 0.00011874967102953525,
#  'plasticfree': 0.00015582548068200915,
#  'bus': 5.2600096776032213e-05,
#  'airpollution': 0.0001288233627305467,
#  'climatechangeisreal': 0.0007448187055957861,
#  'savetheplanet': 0.0005583729487676338,
#  'usa': 0.0003554911947745639,
#  'drought': 4.6938696267140924e-05,
#  'batteries': 6.865043798048267e-07,
#  'coventry': 0.00012178975691722983,
#  'ecofriendly': 1.6840285281987684e-05,
#  'gogreen': 0.00022185473633787748,
#  'cimateaction': 4.096383075596908e-05,
#  'worldveganday': 1.763575872597134e-05,
#  'veganday': 1.763575872597134e-05,
#  'viajes': 0.000197506908107636,
#  'scientists4future': 0.002958544719311564,
#  'ship': 8.412058247575448e-05,
#  'fuelcells': 2.2909947058378342e-05,
#  'technews': 0.00027420688633571493,
#  'techno': 0.0001051287722485652,
#  'scientists': 3.577256210300148e-05,
#  'countries': 4.953855844189181e-05,
#  'energiekrise': 9.551462611292924e-05,
#  'klimawandel': 0.009671975863685034,
#  'blackout': 5.444899611263847e-05,
#  'neubauer': 0.0005644091143612022,
#  'uranium': 7.68037565951331e-06,
#  'consciousplanet': 2.0074303711618004e-06,
#  'climatetech': 8.34110961939535e-06,
#  'video': 0.00026790563820246546,
#  'scientistsforfuture': 0.0002757468858497338,
#  'globalclimatestrike': 0.004687150478941227,
#  'climatepromise': 8.409350563737223e-06,
#  'biodiversityday': 9.18581389608139e-06,
#  'russia': 0.00027980749698135703,
#  'newzealand': 7.683251402410873e-05,
#  'german': 7.322248409837087e-05,
#  'government': 0.00014230063131026406,
#  'america': 7.322248409837087e-05,
#  'human': 2.7894770991528173e-05,
#  'roberthabeck': 2.6172180345870876e-05,
#  'olafscholz': 7.322248409837087e-05,
#  'stromausfall': 1.4645777166011732e-05,
#  'klimaatstaking': 0.00023926841991523572,
#  'meat': 3.672849548213716e-05,
#  'go100re': 2.0117846120412467e-05,
#  'emergenciaclimatica': 0.00036229449335618006,
#  'gnd': 1.195906894565552e-05,
#  'mondaymotivation': 8.525293131275115e-05,
#  'emobility': 6.306039638938362e-05,
#  'cars': 2.5419280282356062e-06,
#  'globalisierung': 0.0006145870707699998,
#  'climatestrikecanada': 0.0005586844708418119,
#  'hintergründe': 0.0,
#  'infographiken': 0.0,
#  'industry40': 0.0,
#  'diversity': 0.0,
#  'chile': 0.0002490766305938039,
#  'yomarcho': 1.0606577638694423e-05,
#  'yellowknife': 1.4801315442724256e-06,
#  'chilemarcha': 6.711985561089491e-05,
#  'dunedin': 2.9960636767490744e-05,
#  'letstakethisoffline': 6.093221500214138e-06,
#  'govegan': 0.0011006289301519357,
#  'savesoilbengaluru': 3.7724522815726636e-06,
#  'climasv': 3.7724522815726636e-06,
#  'peoplepower': 1.8271704630766914e-05,
#  'mapa': 0.000399487026467566,
#  'fasting': 3.909689413324524e-06,
#  'fridays': 0.0003686002201017801,
#  'striking': 0.00011196075381186452,
#  'climatejusticenow': 0.001436985240560155,
#  'mindthegap': 0.0010513667495571988,
#  'globalwarmingisreal': 0.00011196075381186452,
#  'bangladesh': 5.73496652640776e-05,
#  'nomoreemptypromise': 7.95046801616795e-06,
#  'plastic': 8.322810441500169e-05,
#  'humanity': 4.389612187402746e-05,
#  'recycled': 0.00012593023691083154,
#  'plasticwaste': 1.130211755824718e-05,
#  'endfossilfuels': 0.00042057332210391514,
#  'earthdayis365days': 8.124169276504345e-06,
#  'climatecatastrophe': 6.924240682142065e-05,
#  'parisagreement': 0.0005653047859737005,
#  'nowar': 4.2819962127509815e-05,
#  'savesoilsavelife': 0.00029018204452065127,
#  'sharon': 2.4143270164989087e-05,
#  'fff': 0.01663586572665626,
#  'resisters': 2.4105363468157692e-05,
#  'rjo': 2.4105363468157692e-05,
#  'climatebrawl': 0.0005284864689951362,
#  'friday': 0.0005521030864105691,
#  'fridaymorning': 0.0012500154303253228,
#  'schoolstrikeforclimate': 0.00017703701541612357,
#  'schoolstrike': 0.00048586867284970795,
#  'klimaschutz': 0.013976767966908835,
#  'sadhguru': 1.4438686424237187e-06,
#  'klima': 0.004914047820123929,
#  'rassismus': 0.0005894797610451362,
#  'biodiversity': 0.0006714870703331901,
#  'denmark': 2.6782218997189817e-05,
#  'lossanddamage': 0.00016048055928705792,
#  'greenhousegas': 0.0003445267602926881,
#  'riseupmovement': 9.486607032395029e-05,
#  'stopglobalwarming': 5.556807597856062e-05,
#  'climat': 0.00015555803313252602,
#  'world': 0.00025328179419046437,
#  'greed': 2.5556544341229878e-05,
#  'mönchsberggarage': 2.527245429615881e-05,
#  'verkehrswende': 0.002479099810900932,
#  'neinzumloch': 2.527245429615881e-05,
#  'endegelaende': 0.001968946615573927,
#  'thereisnoplanetb': 3.732070206270237e-05,
#  'followbackfriday': 3.0169394220659324e-07,
#  'globalgoals': 0.00012466517101209626,
#  'ff': 0.0009326233547761984,
#  'noplanetb': 0.0007634654022955038,
#  'klimaat': 0.00018129597878891574,
#  'fightfor1point5': 0.001956498657234428,
#  'restoreourearth': 7.041142976825478e-06,
#  'heat': 6.576381039988653e-06,
#  'health': 5.5046325283370356e-05,
#  'justiceclimatique': 6.0961546527932815e-05,
#  'climateactivist': 0.00014246528443690958,
#  'worldclimateactivist': 8.475386466855214e-05,
#  'africanclimatealliance': 8.475386466855214e-05,
#  'naturelovers': 0.0002651246005558976,
#  'trees': 0.00016364516512233155,
#  '気候危機見て見ぬふりはもうできない': 1.47919574185872e-05,
#  'peopleoverprofit': 0.00011519276150229391,
#  'fridayforfutureyouthstrikers': 8.032689302727078e-06,
#  'youthforclimatechange': 8.032689302727078e-06,
#  'climateschool': 8.032689302727078e-06,
#  'don': 8.032689302727078e-06,
#  'if': 8.032689302727078e-06,
#  'youthstrike4climate': 0.000851859660863646,
#  'heatwaves': 7.609442239301013e-05,
#  'foodsystems': 1.7173596816509292e-05,
#  'environnement': 2.1344598497604057e-05,
#  'savecongorainforest': 0.001016460300815593,
#  'climatecantwait': 2.981548254254097e-07,
#  'climatefinance': 6.71688286037642e-05,
#  'thinkgreenactgreen': 7.558738865237842e-06,
#  'kippraconference2022': 6.618643488127256e-05,
#  'climateenergysummit': 6.618643488127256e-05,
#  'onlyoneearth': 0.00010761701675587583,
#  'aws22': 0.0,
#  'educategirlsforclimatejustice': 2.5495128495699736e-05,
#  'letafghangirlslearn': 4.362608591351688e-05,
#  'fffportlandmetro': 2.4774861435163616e-05,
#  'unitebehindthescience': 0.0006594666667520486,
#  'fridaysforfuturehamburg': 3.442376020982438e-06,
#  'hamburg': 0.001144361532339826,
#  'parentsforfuture': 0.0010108943135909894,
#  'futureforfridays': 9.808903038983621e-05,
#  'extinction': 0.00017282768914428273,
#  'endplasticpollution': 0.00011592711001799247,
#  'finland': 2.17197207389762e-05,
#  'worldoceansday': 1.3131362652728872e-05,
#  'nigeria': 0.00010094844215689547,
#  'cycling': 2.3700304331540258e-05,
#  'nft': 1.0919958963017268e-05,
#  'floods': 7.389244667525108e-05,
#  'brazil': 7.287562491306974e-06,
#  'onpoli': 0.00018791718332444887,
#  'elxn43': 0.0003283961686646197,
#  'helsinki': 5.0349155543105063e-05,
#  'ilmasto': 0.0001314592766169135,
#  'ilmastokriisi': 0.0002959148065178875,
#  'ilmastonmuutos': 4.976882123421935e-05,
#  'milano': 0.0001421963558423116,
#  'ourhouseisonfire': 2.0059580248626273e-05,
#  'justice': 7.796713525085656e-05,
#  'cop27': 2.2900658481677355e-05,
#  'makeparisreal': 0.0001307102246783643,
#  'bepartofthesolution_notthepollution': 0.0005184357973169326,
#  'greatgambia': 0.0,
#  'webinar': 2.8215935791578617e-07,
#  'marinescience': 0.0,
#  'spreadawareness': 0.0,
#  'marineeducation': 0.0,
#  'activists': 3.5649940068260484e-07,
#  'droughts': 2.6762956425092986e-06,
#  'wildfires': 0.00016341133488821606,
#  'climatecriminals': 4.855753853718488e-05,
#  '気候変動': 0.00011512217309813549,
#  '環境問題': 4.799111136380729e-05,
#  'climatereparations': 1.161871127051732e-06,
#  'savefuturebangladesh': 6.692393527555367e-06,
#  'strike4climate': 0.00037686037768505735,
#  'alledörferbleiben': 0.002042688144937588,
#  'globalcrisis': 0.00021864892706099722,
#  'keepitintheground': 0.0002917072561242184,
#  'leaveoilintheground': 8.030813977450232e-06,
#  'gocarfree': 8.030813977450232e-06,
#  'bikedontdrive': 5.325933103377111e-05,
#  'fightforonepointfive': 5.325933103377111e-05,
#  'lifesbetterwithtrees': 1.2935962263444987e-06,
#  'kokumsforclimate': 3.6203107095507667e-06,
#  'eacop': 4.8389949042051665e-06,
#  'rewilding': 8.326233265196802e-06,
#  'bankingonabetterfuture': 0.0,
#  'nocgl': 0.00016600874054198834,
#  'wetsuwetenstrong': 8.11508067679283e-05,
#  'midcoastnannas': 2.6760307633131474e-05,
#  'forpeopleforplanet': 2.3941885443666948e-05,
#  'biodiversitycrisis': 1.8249949832839443e-05,
#  'climatemarch': 0.0002158613003363159,
#  'climatedisaster': 5.679164738582357e-06,
#  'edinburghclimatestrike': 2.3465073989237568e-05,
#  'animalliberation': 8.621066317654436e-05,
#  'プラントベース': 3.214403055891594e-05,
#  'おうちごはん': 1.3248717737167274e-05,
#  '気候危機': 0.0003714946229097214,
#  'standforplanet': 2.613638924196845e-05,
#  'lettheearthbreath': 1.9228291148802004e-05,
#  'scientistrebellion': 9.695420433200633e-05,
#  'saveearth': 5.593130584239551e-05,
#  'letearthbreathe': 9.695420433200633e-05,
#  'savethetrees': 4.741553461249706e-05,
#  'waterpollution': 4.741553461249706e-05,
#  'toronto': 2.4600704474567994e-05,
#  'sdg13': 1.7515899427192756e-05,
#  'covid': 0.00023375948765057798,
#  'climatebreakdown': 0.0004931094949274921,
#  'climatehopeful': 3.951932756463275e-05,
#  'youth': 7.650773568033885e-05,
#  'goodfriday': 8.672189410135206e-06,
#  'goodfriday2022': 2.033594492976588e-05,
#  'afrikavuka': 7.981797637523829e-06,
#  'nationaldolphinday': 2.870267720834557e-05,
#  'dolphinday': 2.870267720834557e-05,
#  'captivity': 2.870267720834557e-05,
#  'kills': 2.870267720834557e-05,
#  'stopthegrind': 2.870267720834557e-05,
#  'thursdayvibes': 5.862724901830101e-05,
#  'opwhales': 2.870267720834557e-05,
#  'opseaworld': 2.870267720834557e-05,
#  'defendthewild': 2.870267720834557e-05,
#  'seaspiracy': 2.870267720834557e-05,
#  'happyeaster': 2.870267720834557e-05,
#  'cowspiracy': 2.870267720834557e-05,
#  'plantbased': 0.0002476469346347961,
#  'thursday': 3.1947584701001786e-05,
#  'stopecocide': 7.110011522181278e-05,
#  'corona': 0.004390366273890689,
#  'climatereport': 1.9736396746533872e-05,
#  'dogs': 0.0004163615201396073,
#  'saveplanetearth': 7.301719984961394e-07,
#  'universitystrikeforclimate': 0.0,
#  'buildbackbetter': 4.1536104211116235e-05,
#  'week': 1.0060090075756697e-05,
#  'cleannfts': 2.801455729940338e-05,
#  'ipccreport': 0.00025549469632843625,
#  'children': 5.1354222520926554e-05,
#  'food': 0.0006963435721369277,
#  'crisisclimática': 0.00015490865223956955,
#  'clima': 0.0005449625034684316,
#  'earthhour': 1.8814651250610663e-05,
#  'journeyforsoil': 6.836842975913234e-05,
#  'batman': 6.836842975913234e-05,
#  'photo': 5.765841207026446e-05,
#  'cute': 6.836842975913234e-05,
#  'europeanunion': 6.836842975913234e-05,
#  'luetzerath': 0.000246891979325908,
#  'greta': 0.0037229543243429766,
#  'guwahati': 9.419748801104268e-06,
#  'assam': 3.294551874009796e-06,
#  'faschismus': 0.00013679440648627317,
#  'merkel': 0.0017051659869716824,
#  'youthforclimate': 0.00023396231265654038,
#  'gta': 0.0,
#  'topoli': 3.7817228904798183e-06,
#  'brighters': 5.6800319847330416e-05,
#  'bsb': 5.6800319847330416e-05,
#  'fridaysforfuturebangladesh': 2.4800806577014078e-05,
#  'actionaidbangladesh': 5.6800319847330416e-05,
#  'fffbd': 1.744804638703143e-05,
#  'youthclimatestrike': 7.463720723804997e-05,
#  'globalstrike': 0.0012806290679915938,
#  'globalclimateaction': 0.000258190588421049,
#  'antarctica': 0.00013901997691796717,
#  'arctic': 7.445783878548892e-05,
#  'lucknow': 9.771841568684813e-05,
#  'bethechange': 5.90419234345502e-05,
#  'fckafd': 0.0007203392330969437,
#  'elokapina': 3.1628394340193836e-05,
#  'meintwitterjubiläum': 0.00011837017750087494,
#  'salzburg': 2.2001729403775896e-05,
#  'konzert': 0.00011837017750087494,
#  'dochooserenewables': 1.574197621145157e-05,
#  'ilmastotekoja': 2.5634819572380353e-07,
#  'greenpeace': 0.0009704947604165977,
#  'trump': 0.0007668139146345744,
#  'planttrees': 1.1118979595951049e-05,
#  'save_tree': 1.840025546272084e-05,
#  'action4impact': 4.8708610721119525e-05,
#  'plants': 4.8708610721119525e-05,
#  'phaseoutgas2030': 1.0006370560709166e-05,
#  'crisisoninfiniteearths': 3.1040158628131316e-05,
#  'racialjustice': 7.394556202224065e-05,
#  'blackhistorymonth': 3.1601596926176604e-05,
#  'environmentalism': 3.1601596926176604e-05,
#  'climatelive2022': 6.790720920790924e-06,
#  'savegreen': 9.010571447222443e-05,
#  'savenature': 6.380668614850701e-05,
#  'fff_bangladesh': 6.380668614850701e-05,
#  'skolstrejkförklimatet': 1.410788694978509e-05,
#  'suomi': 7.394545633485086e-05,
#  'plasticpollution': 0.0003016680357981311,
#  'climatesolution': 2.4295594815789444e-05,
#  'vulnerabilities': 6.483315428461232e-05,
#  'visualimpairments': 6.483315428461232e-05,
#  'disasters': 1.346940781115297e-05,
#  '11febbraio': 4.353761185827018e-05,
#  'winter': 0.00018554763546827914,
#  'beautiful': 0.0002987444669739119,
#  'ireland': 2.070564506872713e-05,
#  'emptypromises': 1.1822875250520676e-06,
#  'exxonknew': 1.5959125535788007e-05,
#  'comics': 5.1482902161586314e-05,
#  'comicsforclimate': 6.798774720646535e-05,
#  'wecandothis': 4.827405315599711e-05,
#  'covid_19': 0.0011652463849037944,
#  'theworldiswatching': 2.204046710511445e-05,
#  'fridaysforfutureindia': 4.118064912863995e-06,
#  'mumbai': 3.6414334123614675e-05,
#  'womensclimatestrike': 1.3720536792528535e-06,
#  'kids': 2.4571122652307564e-06,
#  'environmentalprotection': 2.9977782025943295e-05,
#  'greencolonialism': 2.0844641385736964e-05,
#  'beatplasticpollution': 2.1324646334962843e-05,
#  'fornature': 4.955842044674251e-05,
#  'unea5': 4.141108371636355e-05,
#  'pancec': 4.141108371636355e-05,
#  'circulareconomy': 3.392892747687606e-05,
#  'blacklivesmatter': 0.0017939824074049873,
#  'defendthedefenders': 0.0005485246626312067,
#  'blahblahblah': 2.5366228416520115e-05,
#  'blockchain': 0.0009657973776627728,
#  'zukunft': 0.00045058199302952404,
#  'fightfor15': 0.00019418378415687784,
#  'vancouver': 0.00016538447321159252,
#  'bcpoli': 6.040676054588876e-05,
#  'cdnpoli': 0.0004001056638526839,
#  'stoptmx': 1.8297955528589024e-06,
#  'stopcgl': 2.77610214163807e-06,
#  'happynewyear2022': 3.291448477922219e-05,
#  'christmas': 8.096149359920652e-05,
#  'climatestrikes': 0.0007692044755998292,
#  'happyholidays': 1.3443826122532267e-05,
#  'systemchangenotclimatechange': 0.0009649615047404176,
#  'happiness': 1.2893702964546214e-05,
#  'biripi': 3.7463774098461456e-06,
#  'koalas': 3.922165718421299e-05,
#  'wetsuweten': 5.178573264902385e-05,
#  'endegelände': 0.0011958625619822591,
#  'nannassay': 8.004637361854817e-06,
#  'fundourfuturenotgas': 0.0001916330451491158,
#  'vanpoli': 4.153575947675093e-06,
#  'stockholm': 4.008178023611791e-05,
#  '気候危機対策に菜食を': 3.5005770712260594e-05,
#  'saveourkoalas': 7.409198021185494e-05,
#  'crisis': 3.851074800051442e-05,
#  'fastingfridaysforfuture': 1.2714925356712556e-05,
#  'victoriabc': 5.1893392503107055e-05,
#  'страйкзаклімат': 1.2235187325053493e-05,
#  'blackfriday': 0.0009068449215283523,
#  'キッコーマン': 5.53257635774909e-05,
#  'twitter家庭料理部': 2.5584395676049518e-06,
#  'nomoreemptywords': 2.2245705552276256e-05,
#  'fighteverycrisis': 0.0008174690849801239,
#  '大豆ミート': 3.363792116677069e-05,
#  'kretslopp': 4.506094374566907e-05,
#  'klimatkris': 0.00011985688013086756,
#  'climate360sa': 3.724907075583507e-05,
#  'femanism': 1.077265884456482e-05,
#  'climategirl': 1.077265884456482e-05,
#  'copout26': 6.49004221737033e-06,
#  'glasgow': 0.00023325882104104897,
#  'climatescience': 8.995346193276082e-06,
#  'glasgowcop26': 2.2253128300753392e-05,
#  'klimaatmars': 1.2750337089722853e-05,
#  'sustainablegoodlife': 5.5679398091215374e-05,
#  'ndcs': 5.5679398091215374e-05,
#  'learningsociety': 5.5679398091215374e-05,
#  'dearworldleaders': 3.715408095610418e-05,
#  'nuclearpower': 0.00015124554991638496,
#  'exitcoalnow': 3.105997893139509e-09,
#  'netzeroneedsnuclear': 3.105997893139509e-09,
#  'nucléaire': 0.00015124554991638496,
#  'forabolsonaro': 9.309828743701136e-05,
#  'cen': 6.707148385783224e-06,
#  'g20': 0.00012199797215247926,
#  'pressphotography': 9.141250645815071e-05,
#  'roma': 0.0003575628700072021,
#  'news': 3.235539856130863e-05,
#  'divest': 8.959458749981489e-05,
#  'fffmapcount': 0.0002013634958469583,
#  'climatestriking': 4.463611332992216e-05,
#  'whatthecop': 4.784350306991286e-06,
#  'copon4net': 4.784350306991286e-06,
#  'envirocoresubject': 2.1122468862205993e-05,
#  'cleanupstandardchartered': 2.1459036505317423e-06,
#  'treemendous': 2.0527116219755972e-05,
#  'treesarmy': 2.0527116219755972e-05,
#  'phoenix': 2.0527116219755972e-05,
#  'urbanforests': 2.0527116219755972e-05,
#  'gender': 7.314470615940347e-05,
#  'worldleaders': 1.2875685293978024e-05,
#  'smr': 8.382086882498261e-05,
#  'peopleb4profit': 4.878468795186229e-05,
#  'extinctionrebelion': 0.00026712081901463425,
#  'cop26plastics': 4.109649875766893e-05,
#  'dhaka': 1.3945613445832892e-06,
#  'climatecompensation': 0.0,
#  'tellthetruth': 0.0003901948560030959,
#  'ecosystem': 2.4526990603258685e-05,
#  'afdverbot': 0.00022921750458954705,
#  'lakedistrict': 3.1246721419247276e-05,
#  'windermere': 3.1246721419247276e-05,
#  'river': 3.1246721419247276e-05,
#  'lake': 3.1246721419247276e-05,
#  'mondaymotivaton': 3.1246721419247276e-05,
#  'wildlife': 0.00016616675026375272,
#  'peoplevsfossilfuels': 7.673182365268276e-06,
#  'activism': 0.00018534173332142285,
#  'gippsnews': 1.549768889239208e-06,
#  'forests': 0.0001226498123722766,
#  'endangered': 2.8542291655836826e-05,
#  'climatechangedme': 2.499591316715144e-05,
#  'death': 3.79559527709059e-05,
#  'halloween': 1.3832422983631886e-05,
#  'costumeshopping': 3.79559527709059e-05,
#  'happyspookyseason': 3.79559527709059e-05,
#  'peoplearedying': 2.204156955937907e-05,
#  'animalsaredying': 3.79559527709059e-05,
#  'thefutureneedsus': 3.79559527709059e-05,
#  'trickortreat': 3.79559527709059e-05,
#  'onetwoclimatescomingforyou': 3.79559527709059e-05,
#  'scary': 3.79559527709059e-05,
#  'timetoact': 9.752470493647586e-06,
#  'savefairycreek': 0.00012766727435440308,
#  'nyc': 0.0002929142315265673,
#  '11thhourforclimate': 8.676555090205271e-05,
#  'groko': 0.0006486491649035066,
#  'tiredearth': 0.00020686246142124156,
#  'marchaporelclima': 0.00041408606129093704,
#  '24s': 1.6328650662502476e-06,
#  'justiciaporelclima': 5.113118776218076e-05,
#  '24septiembre': 0.00011872966510513883,
#  'rebelforlife': 0.0002698076783874708,
#  'unga': 6.122429984048363e-05,
#  'keingradweiter': 0.002220492613285171,
#  'ecologia': 0.0001274668311345739,
#  'planeta': 2.7779923783391402e-05,
#  'climateweek': 1.7824543091834028e-05,
#  'luxembourg': 6.348851067277176e-05,
#  '世界気候アクション0924': 8.027720121668974e-05,
#  '住友商事の森林破壊を許さない': 8.027720121668974e-05,
#  'stayhome': 0.0004315439446176683,
#  'kenya': 0.00012421899994598061,
#  'tourism': 9.132482369218807e-06,
#  'sttaconsulting': 9.132482369218807e-06,
#  'sustainabletourism': 9.132482369218807e-06,
#  'futures': 1.363286321849143e-05,
#  'cutedog': 1.363286321849143e-05,
#  'dogstrike': 1.363286321849143e-05,
#  'nutrition': 9.800997507815275e-06,
#  'ngo': 4.916637686625926e-05,
#  'elxn44': 8.722011868863808e-06,
#  'cutthebullshit': 9.621874418374215e-06,
#  'wehavethedata': 7.304997571357112e-06,
#  'wehavethetechnology': 1.0437718388225277e-05,
#  'humanchangenotclimatechange': 1.1494767398386773e-05,
#  'species': 0.00013644351371354193,
#  'collapse': 0.00013644351371354193,
#  'losinglife': 1.5606249530883967e-06,
#  'corporationsarekillingus': 1.855197500055678e-05,
#  'holdthemaccountable': 1.855197500055678e-05,
#  'greenhouse': 2.148326482644813e-05,
#  'savetheearth': 1.5172911189646337e-05,
#  'nomoreemptysummits': 2.3398491753812196e-05,
#  'treatacrisislikeacrisis': 2.3150294855698204e-09,
#  'climatecrisisis': 2.845400915177035e-05,
#  'climatestike': 4.3937520175306024e-05,
#  'agriculture': 3.4950417642971804e-05,
#  'victim': 1.69514706092848e-05,
#  'solution': 1.69514706092848e-05,
#  'farmers': 1.640302777310126e-05,
#  'foodsystemshas': 3.6396403865183885e-05,
#  'socialjustice': 0.00021371549889178418,
#  'denialmachine': 1.1127746523691351e-05,
#  'betterfuture': 9.656140360272301e-06,
#  'canada': 0.0007077538371799451,
#  'klimatstrejk': 0.0005319585555244963,
#  'globalclimatejustice': 0.0001727556078295926,
#  'stopshell': 0.00021187606568986962,
#  'withdrawthecap': 0.00019430087971716753,
#  'starwars': 0.0007091572713383712,
#  'extremeweather': 2.1554839526885338e-05,
#  'healthy': 8.777698211517294e-05,
#  'fires': 8.488306864961183e-06,
#  'destruction': 2.8930125145215235e-05,
#  'carbo': 2.8930125145215235e-05,
#  'datteln4': 0.0013037957680754795,
#  'climateactionplan': 1.580353723499706e-05,
#  'stopdeforestation': 3.3870039908317346e-05,
#  'rumors': 8.394426011032492e-05,
#  'alltherumorsaretrue': 8.394426011032492e-05,
#  'listentoscience': 2.3746235388787336e-05,
#  'decarbonizing': 4.1459178439051984e-05,
#  'netzstreikfuersklima': 0.0006336899732533979,
#  'greece': 9.598437541869883e-06,
#  'globalstrikeforfuture': 4.6153901913237505e-05,
#  'garzweiler': 8.762580736636002e-05,
#  'agenda2030': 0.00029398858907475904,
#  'bushfiresurvivorsvsepa': 2.6787601785985785e-06,
#  'carbonemissions': 0.0002651515169322986,
#  'iyd2021': 1.736092236761967e-05,
#  'extinctionisforever': 1.7095964849466426e-06,
#  'globalchange': 5.273571629222317e-05,
#  'notblownwithcyclone': 1.752312559866236e-06,
#  'cliamtestrike': 0.00017301534183482908,
#  'socialjusticeisclimatejustice': 0.00017301534183482908,
#  'savebuxwahaforest': 0.00011311905885646026,
#  'edo': 2.2253447283086083e-05,
#  'rapidreduction2030': 2.2253447283086083e-05,
#  'climatenow': 2.2253447283086083e-05,
#  'bushfire': 2.2253447283086083e-05,
#  'survivors': 2.2253447283086083e-05,
#  'emergency': 0.0001074947352396714,
#  'sea': 5.871819384344138e-05,
#  'overshoot': 3.233771646783991e-05,
#  'basketball': 0.00010317244481240656,
#  'notevengonnatry': 0.00010317244481240656,
#  'lazygovernment': 0.00010317244481240656,
#  'flattenthecurve': 0.0004876086333950566,
#  'borneo': 3.6203107095507667e-06,
#  'saveborneorainforest': 3.6203107095507667e-06,
#  'savebaritoriver': 3.6203107095507667e-06,
#  'americanpolitics': 5.348747265441919e-05,
#  'politicsarekillingpeople': 5.348747265441919e-05,
#  'globalcitizen': 5.348747265441919e-05,
#  'globalsolutions': 5.348747265441919e-05,
#  'flooding': 3.311212552196574e-05,
#  'extreme': 0.00026321072671208005,
#  'thinkglobal': 1.6601364652502315e-05,
#  'actlocal': 1.6601364652502315e-05,
#  'worsethanthanos': 8.284143326052198e-05,
#  'humansaretheproblem': 8.284143326052198e-05,
#  'wecandobetter': 8.284143326052198e-05,
#  'tiktok': 4.3964941827022074e-05,
#  'tiktokdance': 4.3964941827022074e-05,
#  'iliketomoveitmoveit': 4.3964941827022074e-05,
#  'strikeapose': 4.3964941827022074e-05,
#  'vogue': 4.3964941827022074e-05,
#  'planethumor': 4.3964941827022074e-05,
#  'reducereuserecycle': 6.1758684278456035e-06,
#  'wecanbetter': 4.3964941827022074e-05,
#  'earthneedsyou': 4.3964941827022074e-05,
#  'pollutersout': 3.2120626033386905e-05,
#  'girlpower': 1.675952830476155e-05,
#  'listentoexperts': 5.8065088174111405e-05,
#  'climatebrainy': 5.8065088174111405e-05,
#  'itsgettinghotinhere': 6.494784476802184e-05,
#  'coolestsummeryoulleverhave': 6.494784476802184e-05,
#  'marvel': 6.494784476802184e-05,
#  'marvelaudition': 6.494784476802184e-05,
#  'wetlands': 2.672198780667839e-05,
#  'climatecrisisbangladesh': 3.88869055512624e-06,
#  'bangladeshalreadysuffering': 3.88869055512624e-06,
#  'transpride': 0.00010354462645250334,
#  'digitalprotest': 8.103899124800316e-06,
#  'fridaystrikeforclimate': 8.207412759937204e-05,
#  'geethikavenkatesan': 8.207412759937204e-05,
#  'globalheating': 2.1789436143886026e-05,
#  'unitedkingdom': 1.1157083390417115e-05,
#  'howdareyou': 0.0007933274999222812,
#  'पेड़_लगाओ_पृथ्वी_बचाओ': 1.5034664261273447e-05,
#  'planttreesaveearth': 1.5034664261273447e-05,
#  'planttree': 1.5034664261273447e-05,
#  'art': 0.00031631727830657867,
#  'youthtakeover': 3.6203107095507667e-06,
#  'saveaareyforest': 0.00011354864930868594,
#  'plantalife': 3.9077216167237944e-05,
#  'choices': 2.4352325065478465e-05,
#  'lockdown': 0.00017731966365495093,
#  'digitalclimatestrike': 5.177424622786353e-06,
#  'marcodecanaveses': 0.0,
#  'ilmastovaalit': 0.00021617147528489358,
#  '11thhourforclimat': 0.00011293922879690052,
#  'snösätra': 0.00011293922879690052,
#  'worldenvironmentday2021': 5.334794738871421e-06,
#  'schellnhuber': 9.701671478273431e-06,
#  'youth2030': 4.10781106522103e-06,
#  'caminodesantiago': 4.062358871746028e-05,
#  'beyondcoal': 4.706315251944141e-06,
#  'raiseyourstandards': 8.39894206256642e-06,
#  'climatetwitter': 9.671960246955296e-05,
#  '未来のための金曜日': 7.696052880525953e-05,
#  'kurzstreckenflüge': 6.15898306824755e-05,
#  'cycloneamphan': 1.5258278688988448e-05,
#  'ravensburg': 9.405794230639472e-05,
#  'nomowmay': 4.8233069629687995e-06,
#  'ethicalandinformedcitizens': 3.6203107095507667e-06,
#  'ocsbsep': 2.318076981436233e-05,
#  'snow': 0.000205626358403627,
#  'youngpeopleforclimateaction': 1.4529145704880123e-05,
#  'itstheendoftheworldasweknowit': 5.394947867969687e-05,
#  'keepoilintheground': 5.394947867969687e-05,
#  'fossilfuelsarekillingus': 4.736420049918262e-06,
#  'beforeitstoolate': 5.394947867969687e-05,
#  'standwithworkers': 7.653817135190955e-05,
#  'fridayfunday': 0.00040626486924595574,
#  'bicycle': 8.705784613368014e-06,
#  'canpoli': 9.656601785466775e-06,
#  'fcknzs': 0.0005616103635319019,
#  'klimaurteil': 9.031570296961059e-05,
#  'coronavirus': 0.001068529770620735,
#  '温室効果ガス削減目標の大幅引き上げを求めます': 8.01344026721459e-06,
#  'mayday': 6.66359823130071e-05,
#  'peat': 8.606796639715992e-05,
#  'savetheoceans': 2.5668494249945782e-05,
#  'ecologie': 1.7840943664834835e-06,
#  'stopeumercosur': 0.00022930242454774401,
#  '気候危機止めるために学校休みます': 3.5906504926526014e-06,
#  'banplastic': 0.00017613820715043518,
#  'plasticfreeocean': 3.7829543994572716e-05,
#  'childrenareourfuture': 3.7829543994572716e-05,
#  'euclimatelaw': 3.4882204417679983e-05,
#  'endplastic': 1.1283003333282515e-05,
#  'climatepledge': 5.018897569624181e-07,
#  'peaceuponyemen': 2.0527498851950618e-05,
#  'yemencantwait': 1.2617742814788164e-06,
#  'amankumar': 2.807086148336065e-05,
#  'marcheclimat': 1.9247560034764532e-05,
#  'vraieloiclimat': 2.9947307567177097e-06,
#  '16avril': 6.984571998657402e-05,
#  'nantes': 6.984571998657402e-05,
#  'marchepourleclimat': 0.00019201573845566649,
#  'climatresilience': 6.984571998657402e-05,
#  'iamgreta': 9.164222700042822e-05,
#  'intergenerational': 1.3052510496042875e-05,
#  'stopwetlanddegradation': 3.2444416707872646e-06,
#  'climatecrises': 1.903722073178607e-05,
#  'fukushima': 1.63955484126097e-05,
#  'tepco': 1.63955484126097e-05,
#  'tritium': 1.63955484126097e-05,
#  'opgreenrights': 1.63955484126097e-05,
#  'climatealliance': 0.00011259538640973554,
#  'climaterisk': 0.00011259538640973554,
#  'xr': 0.0009620362406588729,
#  'savebugomaforest': 5.258940922641459e-05,
#  'wrongpayroll': 0.0001790047425781437,
#  'police': 2.083583510119317e-05,
#  'dontgiveup': 6.878545244467877e-05,
#  'kabila4sdgs': 1.7664643038903804e-05,
#  'ethoslifestyle': 0.0,
#  'generationclimat': 9.132482369218807e-06,
#  'climatepoli': 2.584340801040838e-05,
#  'fffmar19': 0.00013700472257267146,
#  '私たちの未来を手放さない': 1.6618287872034064e-05,
#  'protecttheoceans': 6.6376343221143126e-06,
#  'katyayan': 4.4713722763483665e-08,
#  'naturephotography': 6.092939665806987e-05,
#  'fossilfree': 4.295530003909359e-05,
#  'womensday': 9.132482369218807e-06,
#  'wakeup': 0.00039935725694713786,
#  'fightforyourhumanright': 1.2675338582141063e-05,
#  'climateart': 5.2233715772667505e-06,
#  'stayathome': 3.790288696078019e-05,
#  '未来のためにお肉を減らそう': 1.9919605540438058e-05,
#  'ヴィーガン': 5.307194214287512e-05,
#  'nzpol': 6.630020268198019e-06,
#  'buses': 7.274822709222686e-05,
#  'costs': 7.274822709222686e-05,
#  'cumbriacoalmine': 1.423415512085714e-05,
#  'ukgov': 1.423415512085714e-05,
#  'throwback': 0.0001287050376331907,
#  'adifferenceofopinion': 8.39372914719335e-05,
#  'killingourselves': 8.39372914719335e-05,
#  'money': 8.39372914719335e-05,
#  'peoplelovemoneymore': 8.39372914719335e-05,
#  'askgerald': 2.6854485409649234e-05,
#  '気候危機に特効薬なし': 1.8779709739968427e-05,
#  '気候も危機': 1.9560715413897488e-05,
#  'greenspaces': 0.0002800468531761274,
#  'actonsahel': 3.1568726633931126e-05,
#  'parisclimateagreement': 5.599444727215348e-07,
#  'digitalstrikesapporo': 1.5323697794132749e-06,
#  'teamcows': 4.739495861042024e-06,
#  'vehicles': 6.34305134360049e-05,
#  'laniña': 1.844431439683819e-05,
#  'indiagate': 4.2198028680407934e-05,
#  'newdelhi': 5.901468761545572e-06,
#  'nomoreemptypomises': 4.2198028680407934e-05,
#  'actnowforfuture': 0.00012038578310761282,
#  'saveourselves': 9.076711091093943e-05,
#  'savehumanity': 9.076711091093943e-05,
#  'madrid': 0.0004950349381239554,
#  'socialdistancing': 8.136916251988691e-05,
#  'eu2020de': 0.00011068157717949236,
#  'indigenousrights': 4.283805548141632e-05,
#  'fightclimateinjustice': 0.0005571285373666591,
#  'wethepeople': 2.4196521155626544e-05,
#  'climateelection': 4.659624014451579e-05,
#  'gambia': 2.932605477548332e-05,
#  'christmas2020': 2.846148208705507e-06,
#  'greenchristmas': 3.1844052758334365e-05,
#  'bushfires': 3.1135786455846416e-05,
#  'hoax': 1.0349673173285446e-05,
#  'firedrillfriday': 0.00021011449160762466,
#  'shoestrike': 0.00017784722710215267,
#  'endcapitalism': 0.00011429137173605445,
#  'endfactoryfarming': 0.00011429137173605445,
#  'saveamazonia': 0.00011429137173605445,
#  '世界気候アクション0925': 3.99982623141216e-06,
#  'internationalhumanrightsday': 5.740533651575405e-05,
#  'euco': 8.47526494048485e-06,
#  'watchlive': 2.686583250343267e-05,
#  'wewanttolive': 6.450154460169729e-05,
#  'covidー19': 0.0003296674336003082,
#  'endperiodplastic': 6.707148385783224e-06,
#  'papua': 0.00012192154763981105,
#  'cop25': 0.0017489539051688391,
#  'unitednations': 3.2941693670161576e-05,
#  'すき焼き': 3.3779327754525224e-05,
#  '仙台麩': 3.3779327754525224e-05,
#  '油麩': 3.3779327754525224e-05,
#  'お腹ペコリン部': 3.3779327754525224e-05,
#  'fundfarmersnotcoal': 1.3310296872096316e-05,
#  'greenfriday': 9.64557624129158e-05,
#  '地球温暖化': 5.2572766050664225e-05,
#  'latinamerica': 4.277019419060386e-05,
#  'saveourcoast': 2.6581511038102178e-05,
#  'noforestnofuture': 4.89019138016836e-06,
#  '仙台': 1.5962788778243155e-06,
#  '女川原発の再稼働に反対します': 0.00010279850136116149,
#  'createforclimatejustice': 3.456762749198627e-05,
#  'artistontwitter': 1.8002732508703015e-05,
#  'priorities': 1.0006370560709166e-05,
#  'coralreef': 0.0,
#  'turtle': 0.00011013620504412357,
#  'share': 0.00011013620504412357,
#  'illustration': 0.00013817370809469668,
#  'draw': 0.00011013620504412357,
#  'savethereef': 0.0,
#  'online': 3.0468167603029227e-05,
#  'election2020': 7.013138348087044e-05,
#  '2ndlockdown': 3.993762440978261e-05,
#  '気候非常事態宣言': 1.1734238590207283e-05,
#  'withdraweia2020': 4.8034741489281e-05,
#  'filthyrich': 1.7677548662992864e-05,
#  'reforestation': 3.9041470697900105e-05,
#  '金曜日アクション': 1.100553291936274e-06,
#  'erneuerbar': 1.739638646569112e-05,
#  'fffdigital': 6.879856661342363e-05,
#  'savewesternghats': 8.395112857914937e-06,
#  'davidattenborough': 2.82260392636725e-05,
#  ...}

# %%
new_centrality = {k: v for k, v in sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse = True)}
new_centrality_nodes = [k for k, v in sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse = True)]

# %% [markdown]
# # 5 - Assortativity

# %% [markdown]
# Weighted graph

# %%
d_weighted = nx.degree_assortativity_coefficient(G, weight = "Count")

# %%
d_weighted
# Out:
# -0.10696016839184015

# %%
# Calcolo avg nearest neigh
## Compute the average degree connectivity of graph.
"""
The average degree connectivity is the average nearest neighbor degree of
    nodes with degree k. For weighted graphs, an analogous measure can
    be computed using the weighted average neighbors degree defined in
    [1]_, for a node `i`, as
"""
avg=nx.k_nearest_neighbors(G, weight = "Count")
y=list(avg.values())

# Calcolo vettore dei gradi
k=G.degree()
x=[]
for item in k:
    x.append(item[1])
    
output = []
for b in x:
       if b not in output:
            output.append(b)

# Plot
plt.plot(output,y,'b.')   
plt.xlabel('Degree k')
plt.ylabel('KNN(k)')

# %%
d=nx.degree_assortativity_coefficient(G)

# %%
d
# Out:
# -0.11311006968566789

# %%
# Calcolo avg nearest neigh
avg=nx.k_nearest_neighbors(G)
y=list(avg.values())

# Calcolo vettore dei gradi
k=G.degree()
x=[]
for item in k:
    x.append(item[1])
    
output = []
for b in x:
       if b not in output:
            output.append(b)

# Plot
plt.plot(output,y,'b.')   
plt.xlabel('Degree k')
plt.ylabel('KNN(k)')
# Out:
# Text(0, 0.5, 'KNN(k)')
